# %%
import sys
sys.path.append("../scripts")

# %%
from binance.client import Client

# %% [markdown]
# ## Initialize client and check connection status

# %%
#Initialize client
api_key, api_secret = open('../data/client_info.txt').read().split('\n')
client = Client(api_key, api_secret)

# %%
#Ping the server
client.ping()
# Out:
# {}

# %% [markdown]
# ## Get account asset info

# %%
existing_assets = []
for asset in client.get_account()['balances']:
    if float(asset['free']) + float(asset['locked']) != 0: existing_assets.append(asset)

# %%
existing_assets = pd.DataFrame(existing_assets)
existing_assets
